# %%
from myquant import add

result = add(10, 5)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from myquant import add
#       3 result = add(10, 5)
#       4 print(result)
#
# ModuleNotFoundError: No module named 'myquant'
